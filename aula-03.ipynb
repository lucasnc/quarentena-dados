# %%
import pandas as pd
imdb = pd.read_csv("https://gist.githubusercontent.com/guilhermesilveira/24e271e68afe8fd257911217b88b2e07/raw/e70287fb1dcaad4215c3f3c9deda644058a616bc/movie_metadata.csv")
imdb.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
imdb['color'].unique()
# Out:
# array(['Color', nan, ' Black and White'], dtype=object)

# %%
imdb['color'].value_counts(normalize=True)
# Out:
# Color               0.9584
#  Black and White    0.0416
# Name: color, dtype: float64

# %%
imdb['director_name'].value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Clint Eastwood          20
# Martin Scorsese         20
# Ridley Scott            17
# Steven Soderbergh       16
# Spike Lee               16
# Tim Burton              16
# Renny Harlin            15
# Oliver Stone            14
# Barry Levinson          13
# Michael Bay             13
# Robert Zemeckis         13
# Sam Raimi               13
# Joel Schumacher         13
# Robert Rodriguez        13
# John Carpenter          13
# Ron Howard              13
# Kevin Smith             12
# Peter Jackson           12
# Brian De Palma          12
# Richard Donner          12
# Wes Craven              12
# Shawn Levy              12
# Tony Scott              12
# Rob Cohen               11
# Rob Reiner              11
# Chris Columbus          11
# Richard Linklater       11
# Francis Ford Coppola    11
#                         ..
# Lisanne Pajot            1
# Luca Guadagnino          1
# Damian Nieman            1
# Jeffrey St. Jules        1
# Chia-Liang Liu           1
# Kari Skogland            1
# Jirí Menzel              1
# Nick Hamm                1
# Cristian Mungiu          1
# Ashish R. Mohan          1
# Michael D. Sellers       1
# Floria Sigismondi        1
# Jonathan Kesselman       1
# Rob Schmidt              1
# Eric Schaeffer           1
# Adam Brooks              1
# Dave Borthwick           1
# Paul Abascal             1
# Lance Kawas              1
# Don Mancini              1
# Ian Sharp                1
# Lance Mungia             1
# Bruce Malmuth            1
# Gary Halvorson           1
# James Dodson             1
# Allan Arkush             1
# Eric Leighton            1
# John Patrick Shanley     1
# Lajos Koltai             1
# Terron R. Parsons        1
# Name: director_name, Length: 2398, dtype: int64

# %%
imdb['num_critic_for_reviews'].describe()
# Out:
# count    4993.000000
# mean      140.194272
# std       121.601675
# min         1.000000
# 25%        50.000000
# 50%       110.000000
# 75%       195.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
imdb['num_critic_for_reviews'].plot(kind='hist')

# %%
imdb['gross'].hist()

# %%
import seaborn as sns

sns.distplot(imdb['gross'])

# %%
imdb.sort_values('gross', ascending=False).head()
# Out:
#      color    director_name  num_critic_for_reviews  duration  \
# 0    Color    James Cameron                   723.0     178.0
# 26   Color    James Cameron                   315.0     194.0
# 29   Color  Colin Trevorrow                   644.0     124.0
# 794  Color      Joss Whedon                   703.0     173.0
# 17   Color      Joss Whedon                   703.0     173.0
#
#      director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                        0.0                   855.0   Joel David Moore
# 26                       0.0                   794.0       Kate Winslet
# 29                     365.0                  1000.0         Judy Greer
# 794                      0.0                 19000.0  Robert Downey Jr.
# 17                       0.0                 19000.0  Robert Downey Jr.
#
#      actor_1_facebook_likes        gross                            genres  \
# 0                    1000.0  760505847.0   Action|Adventure|Fantasy|Sci-Fi
# 26                  29000.0  658672302.0                     Drama|Romance
# 29                   3000.0  652177271.0  Action|Adventure|Sci-Fi|Thriller
# 794                 26000.0  623279547.0           Action|Adventure|Sci-Fi
# 17                  26000.0  623279547.0           Action|Adventure|Sci-Fi
#
#      ... num_user_for_reviews language  country  content_rating       budget  \
# 0    ...               3054.0  English      USA           PG-13  237000000.0
# 26   ...               2528.0  English      USA           PG-13  200000000.0
# 29   ...               1290.0  English      USA           PG-13  150000000.0
# 794  ...               1722.0  English      USA           PG-13  220000000.0
# 17   ...               1722.0  English      USA           PG-13  220000000.0
#
#      title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0        2009.0                  936.0        7.9          1.78
# 26       1997.0                14000.0        7.7          2.35
# 29       2015.0                 2000.0        7.0          2.00
# 794      2012.0                21000.0        8.1          1.85
# 17       2012.0                21000.0        8.1          1.85
#
#     movie_facebook_likes
# 0                  33000
# 26                 26000
# 29                150000
# 794               123000
# 17                123000
#
# [5 rows x 28 columns]

# %%
imdb.sort_values('gross', ascending=False).sample(10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4401  Color       Zack Snyder                   287.0     110.0
# 1834  Color       Judd Apatow                   217.0     133.0
# 3216  Color       Guy Ritchie                    71.0      89.0
# 648   Color  Steven Spielberg                   219.0     169.0
# 4531  Color     Mona Fastvold                    16.0      91.0
# 2492  Color    John Carpenter                   318.0     101.0
# 784   Color         Jon Avnet                   198.0     101.0
# 3966  Color   Bruce Macdonald                     3.0      94.0
# 3460  Color     Daniel Barber                   224.0      97.0
# 440   Color     Todd Phillips                   383.0     102.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4401                      0.0                  1000.0        Kevin Zegers
# 1834                      0.0                   218.0        Romany Malco
# 3216                      0.0                   119.0  Jeanne Tripplehorn
# 648                   14000.0                 13000.0          Vin Diesel
# 4531                      2.0                     9.0        Brady Corbet
# 2492                      0.0                   598.0    Donald Pleasence
# 784                      50.0                  1000.0           Al Pacino
# 3966                    103.0                   111.0         Cheryl Ladd
# 3460                     12.0                   641.0      Jack O'Connell
# 440                     480.0                   461.0           Mason Lee
#
#       actor_1_facebook_likes        gross  \
# 4401                  3000.0   58885635.0
# 1834                  7000.0  109243478.0
# 3216                   990.0     598645.0
# 648                  15000.0  216119491.0
# 4531                   321.0          NaN
# 2492                  2000.0   47000000.0
# 784                  22000.0   40076438.0
# 3966                   544.0          NaN
# 3460                   788.0    1818681.0
# 440                  14000.0  254455986.0
#
#                                    genres  ... num_user_for_reviews language  \
# 4401               Action|Horror|Thriller  ...               1057.0  English
# 1834                       Comedy|Romance  ...                546.0  English
# 3216                       Comedy|Romance  ...                215.0  English
# 648                      Action|Drama|War  ...               2277.0  English
# 4531                                Drama  ...                  2.0  English
# 2492                      Horror|Thriller  ...               1191.0  English
# 784   Action|Crime|Drama|Mystery|Thriller  ...                248.0  English
# 3966    Adventure|Biography|Drama|Romance  ...                 15.0  English
# 3460          Action|Crime|Drama|Thriller  ...                224.0  English
# 440                                Comedy  ...                402.0  English
#
#            country  content_rating      budget  title_year  \
# 4401           USA               R  26000000.0      2004.0
# 1834           USA               R  26000000.0      2005.0
# 3216            UK               R  10000000.0      2002.0
# 648            USA               R  70000000.0      1998.0
# 4531        Norway       Not Rated   1100000.0      2014.0
# 2492           USA               R    300000.0      1978.0
# 784            USA               R  60000000.0      2008.0
# 3966  South Africa              PG   4000000.0      2014.0
# 3460            UK               R   7300000.0      2009.0
# 440            USA               R  80000000.0      2011.0
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 4401                 2000.0        7.4          2.35                 7000
# 1834                  966.0        7.1          1.85                    0
# 3216                  711.0        3.6          1.85                  725
# 648                 14000.0        8.6          1.85                22000
# 4531                  287.0        4.9          2.35                  234
# 2492                  742.0        7.9          2.35                12000
# 784                 14000.0        6.0          2.35                    0
# 3966                  476.0        4.7           NaN                  365
# 3460                  698.0        7.2          2.35                    0
# 440                   670.0        6.5          2.35                56000
#
# [10 rows x 28 columns]

# %%
color_or_bw = imdb.query("color in ['Color', ' Black and White']")
len(color_or_bw)
# Out:
# 5024

# %%
color_or_bw['color_0_ou_1'] = (color_or_bw['color']=='Color') * 1
color_or_bw.head()
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi  ...
#
#   language country  content_rating       budget title_year  \
# 0  English     USA           PG-13  237000000.0     2009.0
# 1  English     USA           PG-13  300000000.0     2007.0
# 2  English      UK           PG-13  245000000.0     2015.0
# 3  English     USA           PG-13  250000000.0     2012.0
# 5  English     USA           PG-13  263700000.0     2012.0
#
#    actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 0                   936.0        7.9         1.78                 33000
# 1                  5000.0        7.1         2.35                     0
# 2                   393.0        6.8         2.35                 85000
# 3                 23000.0        8.5         2.35                164000
# 5                   632.0        6.6         2.35                 24000
#
#   color_0_ou_1
# 0            1
# 1            1
# 2            1
# 3            1
# 5            1
#
# [5 rows x 29 columns]

# %%
color_or_bw['color_0_ou_1'].value_counts()
# Out:
# 1    4815
# 0     209
# Name: color_0_ou_1, dtype: int64

# %%
sns.scatterplot(data=color_or_bw, x='color_0_ou_1', y='gross')

# %%
color_or_bw.groupby('color').mean()['gross']
# Out:
# color
#  Black and White    3.245702e+07
# Color               4.902619e+07
# Name: gross, dtype: float64

# %%
color_or_bw.groupby('color').mean()['imdb_score']
# Out:
# color
#  Black and White    7.227273
# Color               6.409533
# Name: imdb_score, dtype: float64

# %%
imdb = imdb.drop_duplicates()

# %%
imdb_usa = imdb.query("country == 'USA'")
imdb_usa.sort_values("budget", ascending=False).head()
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 1     Color  Gore Verbinski                   302.0     169.0
# 5     Color  Andrew Stanton                   462.0     132.0
# 7     Color    Nathan Greno                   324.0     100.0
# 6     Color       Sam Raimi                   392.0     156.0
# 3461  Color       Sam Raimi                   392.0     156.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 1                       563.0                  1000.0    Orlando Bloom
# 5                       475.0                   530.0  Samantha Morton
# 7                        15.0                   284.0     Donna Murphy
# 6                         0.0                  4000.0     James Franco
# 3461                      0.0                  4000.0     James Franco
#
#       actor_1_facebook_likes        gross  \
# 1                    40000.0  309404152.0
# 5                      640.0   73058679.0
# 7                      799.0  200807262.0
# 6                    24000.0  336530303.0
# 3461                 24000.0  336530303.0
#
#                                                  genres  ...  \
# 1                              Action|Adventure|Fantasy  ...
# 5                               Action|Adventure|Sci-Fi  ...
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# 6                              Action|Adventure|Romance  ...
# 3461                           Action|Adventure|Romance  ...
#
#      num_user_for_reviews language  country  content_rating       budget  \
# 1                  1238.0  English      USA           PG-13  300000000.0
# 5                   738.0  English      USA           PG-13  263700000.0
# 7                   387.0  English      USA              PG  260000000.0
# 6                  1902.0  English      USA           PG-13  258000000.0
# 3461               1902.0  English      USA           PG-13  258000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 1         2007.0                 5000.0        7.1          2.35
# 5         2012.0                  632.0        6.6          2.35
# 7         2010.0                  553.0        7.8          1.85
# 6         2007.0                11000.0        6.2          2.35
# 3461      2007.0                11000.0        6.2          2.35
#
#      movie_facebook_likes
# 1                       0
# 5                   24000
# 7                   29000
# 6                       0
# 3461                    0
#
# [5 rows x 28 columns]

# %%
budget_gross = imdb_usa[['budget', 'gross']].dropna().query('budget > 0 | gross > 0')

sns.scatterplot(x='budget', y='gross', data = budget_gross)

# %%
imdb_usa['lucro'] = imdb_usa['gross'] - imdb_usa['budget']

budget_gross = imdb_usa.query('budget > 0 | gross > 0')[['budget', 'lucro']].dropna()

sns.scatterplot(x='budget', y='lucro', data = budget_gross)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
budget_gross = imdb_usa.query('budget > 0 | gross > 0')[['title_year', 'lucro']].dropna()

sns.scatterplot(x='title_year', y='lucro', data = budget_gross)

# %%
filmes_por_diretor = imdb_usa['director_name'].value_counts()
filmes_por_diretor.head()
# Out:
# Steven Spielberg    24
# Martin Scorsese     20
# Clint Eastwood      20
# Woody Allen         18
# Tim Burton          16
# Name: director_name, dtype: int64

# %%
gross_director = imdb_usa[['director_name', 'gross']].set_index('director_name').join(filmes_por_diretor, on='director_name')
gross_director.columns=['dindin', 'filmes_irmaos']

budget_gross = imdb_usa.query('budget > 0 | gross > 0')[['title_year', 'lucro']].dropna()

sns.scatterplot(x='filmes_irmaos', y='dindin', data = gross_director)

# %%
sns.pairplot(data = imdb_usa[['gross', 'budget', 'lucro', 'title_year']])

# %% [markdown]
# # Plotar e analisar o Boxplot da média (coluna imbd_score) dos filmes em preto e branco e coloridos.

# %%
sns.boxplot(x='color', y='imdb_score', data=color_or_bw)

# %% [markdown]
# # No gráfico de budget por lucro temos um ponto com muito custo e prejuizo, descubra com é esse filme (budget próximo de 2.5).

# %%
imdb_usa.sort_values('lucro').head(1)['movie_title']
# Out:
# 5    John Carter
# Name: movie_title, dtype: object

# %% [markdown]
# # Em aula falamos que talvez, filmes mais recentes podem ter prejuizo pois ainda não tiveram tempo de recuperar o investimento. Analise essas informações e nos conte quais foram suas conclusões.

# %%
lucro_year = imdb_usa[["title_year", "lucro"]].dropna()

sns.scatterplot(x="title_year", y="lucro", data=lucro_year)

# %% [markdown]
# # Quais foram os filmes da decada pré 2° guerra que tiveram muito lucro.

# %%
pre_war = imdb_usa.query('title_year < 1940').sort_values('lucro', ascending=False).dropna()
pre_war[['movie_title', 'lucro']].head(2)
# Out:
#                            movie_title        lucro
# 3970               Gone with the Wind   194678278.0
# 4449  Snow White and the Seven Dwarfs   182925485.0

# %% [markdown]
# # No gráfico de filmes_irmaos por dindin temos alguns pontos estranhos entre 15 e 20. Confirme a tese genial do Paulo que o cidadão estranho é o Woody Allen.

# %%
gross_director.query('filmes_irmaos > 16 & filmes_irmaos < 20')
# Out:
#                    dindin  filmes_irmaos
# director_name
# Woody Allen     7496522.0           18.0
# Woody Allen    16684352.0           18.0
# Woody Allen    13383737.0           18.0
# Woody Allen    10569071.0           18.0
# Woody Allen     9714482.0           18.0
# Woody Allen    33404871.0           18.0
# Woody Allen    17071230.0           18.0
# Woody Allen     3203044.0           18.0
# Woody Allen    14792779.0           18.0
# Woody Allen     4839383.0           18.0
# Woody Allen    10763469.0           18.0
# Woody Allen     5306447.0           18.0
# Woody Allen     3247816.0           18.0
# Woody Allen     5032496.0           18.0
# Woody Allen    39200000.0           18.0
# Woody Allen           NaN           18.0
# Woody Allen           NaN           18.0
# Woody Allen           NaN           18.0

# %% [markdown]
# # Calcular a correlação apenas dos filmes pós anos 2000 (Jogar fora filmes antes de 2000) e interpretar essa correlação.

# %%
filmes_depois_de_2000 = imdb_usa.query('title_year >= 2000')
filmes_depois_de_2000[["gross", "budget", "lucro", "title_year"]].corr()
# Out:
#                gross    budget     lucro  title_year
# gross       1.000000  0.709233  0.770642    0.105342
# budget      0.709233  1.000000  0.097307    0.058550
# lucro       0.770642  0.097307  1.000000    0.035039
# title_year  0.105342  0.058550  0.035039    1.000000

# %% [markdown]
# # Tentar encontrar uma reta, pode ser com uma régua no monitor (não faça isso), com o excel/google sheets, com o python, no gráfico que parece se aproximar com uma reta (por exemplo budget/lucro, gross/lucro)

# %%
sns.pairplot(imdb_usa, y_vars='lucro', x_vars=['budget', 'gross'], height=6, kind='reg')

# %% [markdown]
# # Analisar e interpretar a correlação de outras variáveis além das feitas em sala (notas é uma boa). Número de avaliações por ano pode ser também uma feature.

# %%
votos_por_ano = imdb_usa.groupby('title_year')['num_voted_users'].mean()
imdb_usa_votos_por_ano = imdb_usa.join(votos_por_ano, on='title_year', rsuffix='rs')
imdb_usa_votos_por_ano.rename(columns={'num_voted_usersrs': 'votos_por_ano'}, inplace=True)
imdb_usa_votos_por_ano[['title_year', 'votos_por_ano']].corr()
# Out:
#                title_year  votos_por_ano
# title_year       1.000000       0.142897
# votos_por_ano    0.142897       1.000000

# %%
sns.scatterplot(x='title_year', y='votos_por_ano', data=imdb_usa_votos_por_ano)
